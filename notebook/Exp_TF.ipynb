# %% [markdown]
# ### 测试input_data文件

# %%
import os
os.getcwd()
# Out:
# '/home/num_24/\xe6\xa1\x8c\xe9\x9d\xa2/mywork/github/TFDeepSurv/notebook'

# %%
os.chdir("/home/num_24/\xe6\xa1\x8c\xe9\x9d\xa2/mywork/github/TFDeepSurv")
os.getcwd()
# Out:
# '/home/num_24/\xe6\xa1\x8c\xe9\x9d\xa2/mywork/github/TFDeepSurv'

# %%
import input_data

# %%
data_sets = input_data.read_data_sets("/home/num_24/\xe6\xa1\x8c\xe9\x9d\xa2/mywork/github/TFDeepSurv/data/", validation_ratio = 0.2)

# %%
print data_sets

# %%
train_data, validation_data, test_data = data_sets.train, data_sets.validation, data_sets.test
print train_data

# %%
num_epoch = 5
batch_size = 5
for i in range(num_epoch):
    for j in range(train_data.num_examples / batch_size):
        print train_data.next_batch(batch_size)
# Out:
# (array([[ 0.2869072 ,  0.54156125,  0.93438808],
#        [ 0.0127064 ,  0.56872074,  0.28371888],
#        [ 0.00928336,  0.02626285,  0.09098535],
#        [ 0.36474482,  0.58097251,  0.68731316],
#        [ 0.96545101,  0.70043073,  0.17913228]]), array([[86,  0],
#        [67,  0],
#        [52,  1],
#        [50,  1],
#        [ 1,  1]]))
# (array([[ 0.86622472,  0.51656772,  0.827538  ],
#        [ 0.33435118,  0.76911504,  0.23641484],
#        [ 0.74673571,  0.92934918,  0.89436563],
#        [ 0.11881915,  0.58096508,  0.11561885],
#        [ 0.27693399,  0.29589178,  0.14630032]]), array([[97,  0],
#        [83,  1],
#        [78,  0],
#        [38,  0],
#        [ 0,  0]]))
# (array([[ 0.78673135,  0.3275156 ,  0.42547069],
#        [ 0.15061715,  0.62164469,  0.09426884],
#        [ 0.95343366,  0.514366  ,  0.00111175],
#        [ 0.95809243,  0.43913524,  0.34999977],
#        [ 0.44391041,  0.84976543,  0.01976806]]), array([[50,  0],
#        [40,  0],
# ...
